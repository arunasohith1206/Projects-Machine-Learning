# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
data = pd.read_excel("C:/Users/HP/Downloads/creditcard.xlsx")

# %%
data.head()

# %%
pd.options.display.max_columns = None    #to display all columns

# %%
data.head()

# %%
data.tail()

# %%
data.shape

# %%
print("Number of rows",data.shape[0])
print("Number of columns",data.shape[1])

# %%
data.info()

# %%
data.isnull().sum()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()

# %%
data=data.drop(['Time'],axis=1)

# %%
data.shape

# %%
data.duplicated().any()

# %%
data = data.drop_duplicates()

# %%
data.shape

# %%
284807-275663

# %% [markdown]
# Not Handling imbalanced

# %%
data['Class'].value_counts()

# %%
import seaborn as sns
sns.countplot(data['Class'])

# %% [markdown]
# Score feature matrix in X and response (target) in vector y

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %% [markdown]
# Splitting the data into the training set and testing set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_sate=42)

# %% [markdown]
# Handling imbalanced data

# %%
#under sampling
#over sampling

# %%
#under sampling
normal = data[data["class"]==0]
fraud = data[data["class"]==0]

# %%
normal.shape

# %%
fraud.shape

# %%
normal_sample = normal.sample(n=473)

# %%
normal_sample.shape

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data = ['class'].values_counts()

# %%
new_data.head()

# %%
X = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_sate=42)

# %%
from sklearn.ensemble import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.pred(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred)

# %%
recall_score(y_test,y_pred)

# %%
f1_score(y_test,y_pred)

# %% [markdown]
# Decision Classifier classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(y_train,y_test)
y_pred1 = dtc.(X_test)

# %%
accuracy_score(y_test,y_pred1)

# %%
precision_score(y_test,y_pred1)

# %%
recall_score(y_test,y_pred1)

# %%
f1_score(y_test,y_pred1)

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
y_pred2 = rfc.(X_test)

# %%
accuracy_score(y_test,y_pred1)

# %%
precision_score(y_test,y_pred1)

# %%
recall_score(y_test,y_pred1)

# %%
f1_score(y_test,y_pred1)

# %%
final_data = pd.DataFrame({'Models':['lr','dtc','rfc'],ACC:[accuracy_score(y_test,y_pred)*100,
                                               accuracy_score(y_test,y_pred1)*100,
                                               accuracy_score(y_test,y_pred2)*100]})

# %%
sns.barplot(final_data['models'],final_data['ACC'])
